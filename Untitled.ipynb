# %%
import pandas as pd 
import numpy as np
import matplotlib as plt

# %%
data = pd.read_csv("./data/data.csv")

# %%
data
# Out:
#                                                     Name  \
# 0                                     Tetrafluoromethane
# 1                                                METHANE
# 2                                       HEXAFLUOROETHANE
# 3                                       TRIFLUOROMETHANE
# 4                            2.2.2-trifluoroacetonitrile
# ...                                                  ...
# 11691  (2S)-2-acetamido-3-(3.5-dibromo-4-hydroxypheny...
# 11692  (1R.3R.8R.12S.13R.17R.18Z.20Z.24R.25S.26S)-12-...
# 11693                                          PIROXICAM
# 11694  2-[[4-(2-chloro-4-methylsulfonylphenyl)diazeny...
# 11695  trimethyl-[2-[4-oxo-4-(2-trimethylazaniumyleth...
#
#                                                   SMILES  Molar Mass  \
# 0                                            C(F)(F)(F)F     88.0000
# 1                                                      C     16.0400
# 2                                     C(C(F)(F)F)(F)(F)F    138.0100
# ...

# %%
data.columns
# Out:
# Index(['Name', 'SMILES', 'Molar Mass', 'CAS Number',
#        'Experimental Solubility in Water', 'Temperature',
#        'Experiment Reference', 'Datagroup', 'Solvation Energy',
#        'Dipole Moment', 'Molecular Volume', 'Molecular Surface Area', 'QXX',
#        'QYY', 'QZZ', 'HOMO', 'LUMO', 'gap', 'Standard InChIKey', 'Cal logP',
#        'Cal MR', 'TPSA', 'Labute ASA', 'Balaban J index', 'Bertz CT index',
#        'Isomer'],
#       dtype='object')
